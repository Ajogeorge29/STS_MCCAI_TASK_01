# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajogeorge29/STS_MCCAI_TASK_01/blob/main/STS_TASK_nnUNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cloning and installing nnU-Net from the repository
# !git clone https://github.com/MIC-DKFZ/nnUNet.git
# %cd nnUNet
# !pip install -e .
# Out:
# Cloning into 'nnUNet'...
# remote: Enumerating objects: 14005, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 14005 (delta 107), reused 77 (delta 71), pack-reused 13859 (from 2)
# Receiving objects: 100% (14005/14005), 8.63 MiB | 4.59 MiB/s, done.
# Resolving deltas: 100% (10665/10665), done.
# /content/nnUNet
# Obtaining file:///content/nnUNet
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
# ...

# %%
# !pip install --upgrade git+https://github.com/FabianIsensee/hiddenlayer.git
# Out:
# ...
#   Cloning https://github.com/FabianIsensee/hiddenlayer.git to /tmp/pip-req-build-qmb50h5e
#   Running command git clone --filter=blob:none --quiet https://github.com/FabianIsensee/hiddenlayer.git /tmp/pip-req-build-qmb50h5e
#   Resolved https://github.com/FabianIsensee/hiddenlayer.git to commit b7263b6dc4569da1b6dea5964e1eac78fa32fa77
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for hiddenlayer: filename=hiddenlayer-0.2-py3-none-any.whl size=20004 sha256=4173663e0ffbb3aa7163cd88cbc4eb7da2f617d9d7e50e815ca5087bdea17ec5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k7dv27je/wheels/5e/bb/33/76bf11a993485ba52708dbbb7f9612cbb8bb640d4580967ab1
# Successfully built hiddenlayer
# ...

# %%
import torch

print(torch.__version__)
# Out:
# 2.6.0+cu124

# %%
import torch

if torch.cuda.is_available():
    device = torch.device('cuda:0')
    print(f"Using device: {device}")
else:
    device = torch.device('cpu')
    print("CUDA is not available, using CPU.")
# Out:
# Using device: cuda:0

# %%
# !pip install nibabel==5.2.1
# !pip install SimpleITK==2.3.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 62.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nibabel
#     Found existing installation: nibabel 5.3.2
#     Uninstalling nibabel-5.3.2:
#       Successfully uninstalled nibabel-5.3.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SimpleITK
#     Found existing installation: simpleitk 2.5.2
#     Uninstalling simpleitk-2.5.2:
#       Successfully uninstalled simpleitk-2.5.2
# ...

# %%
# %cd nnUNet
# Out:
# /content/nnUNet

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import os module
import os

# Define paths for the required directories
data_path = '/content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2'
raw_data_path = os.path.join(data_path, 'nnUNet_raw')
preprocessed_path = os.path.join(data_path, 'nnUNet_preprocessed')
results_path = os.path.join(data_path, 'nnUNet_results')

# Set environment variables
os.environ['nnUNet_raw'] = raw_data_path
os.environ['nnUNet_preprocessed'] = preprocessed_path
os.environ['nnUNet_results'] = results_path

# Verify environment variables are set correctly
print(os.environ['nnUNet_raw'])
print(os.environ['nnUNet_preprocessed'])
print(os.environ['nnUNet_results'])
# Out:
# /content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/nnUNet_raw
# /content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/nnUNet_preprocessed
# /content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/nnUNet_results

# %%
# !nnUNetv2_plan_and_preprocess -d 111 -c 3d_fullres --verify_dataset_integrity

# %%
# !pip install triton

# %%
import torch._dynamo
torch._dynamo.config.suppress_errors = True

# %%
# %env TORCH_LOGS="+dynamo"
# %env TORCHDYNAMO_VERBOSE=1
# Out:
# env: TORCH_LOGS="+dynamo"
# env: TORCHDYNAMO_VERBOSE=1

# %%
#!nnUNetv2_train 110 3d_fullres 0 -tr nnUNetTrainer_10epochs | tee train_log.txt

# %%
# Define paths for the required directories
data_path = '/content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2'
raw_data_path = os.path.join(data_path, 'nnUNet_raw')
preprocessed_path = os.path.join(data_path, 'nnUNet_preprocessed')
results_path = os.path.join(data_path, 'nnUNet_results')

# Set environment variables
os.environ['nnUNet_raw'] = raw_data_path
os.environ['nnUNet_preprocessed'] = preprocessed_path
os.environ['nnUNet_results'] = results_path

# Remove problematic environment variables
os.environ.pop('TORCH_LOGS', None)
os.environ.pop('TORCHDYNAMO_VERBOSE', None)

# Verify environment variables are set correctly
print(os.environ['nnUNet_raw'])
print(os.environ['nnUNet_preprocessed'])
print(os.environ['nnUNet_results'])

# Plan and preprocess the dataset
# !nnUNetv2_plan_and_preprocess -d 110 -c 3d_fullres --verify_dataset_integrity

# Train the model
# !nnUNetv2_train 111 3d_fullres 0 -tr nnUNetTrainer_500epochs | tee train_log.txt
# Out:
# /content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/nnUNet_raw
# /content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/nnUNet_preprocessed
# /content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/nnUNet_results

# %%
# Define the input path for the imagesTs data of Dataset 111
# Ensure this path points to the folder with the images to be predicted
validation_data_path = '/content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/nnUNet_raw/Dataset111_UntrainedPseudoLabels/imagesTs'

# Define the desired output directory for predictions on Dataset 111
predictions_output_path = '/content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/nnUNet_results/Dataset111_UntrainedPseudoLabels/predictions_from_best_500epochs_model_modifiedtests' # Example output path

# Define the path to the trained model folder (contains the checkpoint file)
# This is the directory for the nnUNetTrainer_500epochs run on Dataset 111, fold 0
# The dataset.json is expected in the parent directory of the fold folder
model_training_output_dir = '/content/drive/MyDrive/STS_Task1SWIN_UNETR/nnUNet_data2/Dataset111_UntrainedPseudoLabels/nnUNetTrainer_500epochs__nnUNetPlans__3d_fullres'
model_folder_path = os.path.join(model_training_output_dir, 'fold_0')


# Ensure the output directory exists
import os
os.makedirs(predictions_output_path, exist_ok=True)

# Run the prediction command
# -i should point to the directory containing the imagesTs files
# -o should point to the desired output directory for the predictions
# -d is the dataset ID (111)
# -c is the configuration (3d_fullres)
# -f is the fold number (0)
# -chk is the checkpoint file name (checkpoint_best.pth)
# -tr is the trainer class name (nnUNetTrainer_500epochs)
# Need to be in the /content/nnUNet directory for this to work
# %cd /content/nnUNet
# !nnUNetv2_predict -i {validation_data_path} -o {predictions_output_path} -d 111 -c 3d_fullres -f 0 -chk checkpoint_best.pth -tr nnUNetTrainer_500epochs
# Out:
# /content/nnUNet
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# There are 3 cases in the source folder
# I am processing 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 3 cases that I would like to predict
#
# Predicting STS25_Validation_0001:
# perform_everything_on_device: True
# 100% 990/990 [15:38<00:00,  1.05it/s]
# Prediction on device was unsuccessful, probably due to a lack of memory. Moving results arrays to CPU
# 100% 990/990 [17:00<00:00,  1.03s/it]
# sending off prediction to background worker for resampling and export
# done with STS25_Validation_0001
#
# ...
